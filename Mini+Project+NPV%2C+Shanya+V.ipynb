# %%
import numpy as np
import pandas as pd

# %%
employee=pd.read_csv('C:/Users/DELL/Downloads/NPV - Mini - Question-1 (1)/emp_health.csv')
employee
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 2     i10014   28    male  33.000          3   rarely    no      south
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 4     i10016   32    male  28.880          0    party    no  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1333  i11345   50    male  30.970          3       no    no       west
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
# 1336  i11348   21  female  25.800          0    party    no  southwest
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# ...

# %%
#1. How many employees above 50 age smoke, what is their average expenditure on health management?

# %%
x=employee[(employee['age']>50) & (employee['smoke']=='yes')]
x
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 11    i10023   62  female  26.290          0    daily   yes      south
# 39    i10051   60    male  39.900          0    daily   yes  southwest
# 55    i10067   58    male  36.955          2  weekend   yes  northwest
# 58    i10070   53  female  22.880          1    daily   yes      south
# 86    i10098   57  female  31.160          0       no   yes  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1265  i11277   64    male  23.760          0  weekend   yes  southeast
# 1284  i11296   61    male  36.300          1    daily   yes  southwest
# 1301  i11313   62    male  30.875          3       no   yes       west
# 1321  i11333   62    male  26.695          0    daily   yes       east
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure
# 11    27808.72510
# 39    48173.36100
# 55    47496.49445
# 58    23244.79020
# ...

# %% [markdown]
# As mentioned above, there are 64 employees who are above the age of 50 and smoke.

# %%
avg=x['expenditure'].mean()
print ("Average of the aforementioned employees' health expenditure is", avg)
# Out:
# Average of the aforementioned employees' health expenditure is 38820.22308234375

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %%
#2. How many female employees did not consume alcohol daily. What is their proportion with respect 
#to total female employees?

# %%
y=employee[(employee['sex']=='female') & (employee['alcohol']!='daily')]
y
# Out:
#           id  age     sex    bmi  dependent  alcohol smoke       zone  \
# 5     i10017   31  female  25.74          0       no    no      south
# 7     i10019   37  female  27.74          3  weekend    no  northwest
# 9     i10021   60  female  25.84          0       no    no  northwest
# 13    i10025   56  female  39.82          0  weekend    no      south
# 16    i10028   52  female  30.78          1    party    no      north
# ...      ...  ...     ...    ...        ...      ...   ...        ...
# 1330  i11342   57  female  25.74          2       no    no  southeast
# 1332  i11344   52  female  44.70          3    party    no  southwest
# 1335  i11347   18  female  36.85          0  weekend    no  southeast
# 1336  i11348   21  female  25.80          0    party    no  southwest
# 1337  i11349   61  female  29.07          0       no   yes       west
#
#       expenditure
# 5      3756.62160
# 7      7281.50560
# 9     28923.13692
# 13    11090.71780
# 16    10797.33620
# ...

# %% [markdown]
# There are 453 women employees who do not smoke daily.

# %%
y2=employee[(employee['sex']=='female')]
y2
# Out:
#           id  age     sex    bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.90          0    daily   yes  southwest
# 5     i10017   31  female  25.74          0       no    no      south
# 6     i10018   46  female  33.44          1    daily    no      south
# 7     i10019   37  female  27.74          3  weekend    no  northwest
# 9     i10021   60  female  25.84          0       no    no  northwest
# ...      ...  ...     ...    ...        ...      ...   ...        ...
# 1332  i11344   52  female  44.70          3    party    no  southwest
# 1334  i11346   18  female  31.92          0    daily    no       east
# 1335  i11347   18  female  36.85          0  weekend    no  southeast
# 1336  i11348   21  female  25.80          0    party    no  southwest
# 1337  i11349   61  female  29.07          0       no   yes       west
#
#       expenditure
# 0     16884.92400
# 5      3756.62160
# 6      8240.58960
# 7      7281.50560
# 9     28923.13692
# ...

# %% [markdown]
# There are in total 662 female employees.

# %%
#in order to take the ratio of female employees who do not smoke daily with total female employees
#There are 453 women employees who do not smoke daily.
#There are in total 662 female employees.

ratio=453/662
print('Required ratio:',ratio)
# Out:
# Required ratio: 0.6842900302114804

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %%
#3. Display zone wise average expenditure of employees on health.

# %%
z=employee.groupby('zone')['expenditure'].mean()
print("Zone wise average expenditure is :  ",z)
# Out:
# Zone wise average expenditure is :   zone
# east         13774.679941
# north        14102.583403
# northeast    13694.721724
# northwest    12151.702619
# south        14715.689519
# southeast    14452.949680
# southwest    12717.083869
# west         12182.998872
# Name: expenditure, dtype: float64

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %%
#4. Employees of which zone did maximum expenditure on health

# %%
pd.pivot_table(employee, values='expenditure',index='zone', aggfunc= np.sum).sort_values(by='expenditure',ascending=False).iloc[0:1]
# Out:
#        expenditure
# zone
# east  3.608966e+06

# %% [markdown]
# Employees of East Zone did maximum expenditure on health.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %%
# 5. What is the minimum expenditure done by any employee in organization

# %%
min=employee['expenditure'].min()
print('The minimum expenditure done by any employee in the organization is : ',min)
# Out:
# The minimum expenditure done by any employee in the organization is :  1121.8739

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %%
#6. What is average expenditure of employees who have 2 or lesser dependents

# %%
d=employee[(employee['dependent']<=2)]
d
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 4     i10016   32    male  28.880          0    party    no  northwest
# 5     i10017   31  female  25.740          0       no    no      south
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1331  i11343   23  female  33.400          0    daily    no  southwest
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
# 1336  i11348   21  female  25.800          0    party    no  southwest
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure
# 0     16884.92400
# 1      1725.55230
# 3     21984.47061
# 4      3866.85520
# ...

# %%
avg1=d['expenditure'].mean()
print('The average expenditure of employees who have 2 or lesser dependents is :' ,avg1)
# Out:
# The average expenditure of employees who have 2 or lesser dependents is : 13040.970970948145

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %%
#7. How many employees are below age of 20 years. What is their average BMI

# %%
a=employee[(employee['age']<20)]
a
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 15    i10027   19    male  24.600          1    party    no  southwest
# 22    i10034   18    male  34.100          0    daily    no      south
# 31    i10043   18  female  26.315          0    daily    no      north
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1315  i11327   18    male  28.310          1  weekend    no       east
# 1316  i11328   19  female  20.600          0  weekend    no  southwest
# 1317  i11329   18    male  53.130          0    party    no  southeast
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
#
#       expenditure
# 0     16884.92400
# 1      1725.55230
# 15     1837.23700
# 22     1137.01100
# ...

# %% [markdown]
# There are 137 employees below the age of 20 years.

# %%
avgBMI=a['bmi'].mean()
print ("Average BMI of the 137 employees with age<20years is", avgBMI)
# Out:
# Average BMI of the 137 employees with age<20years is 29.971496350364966

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %%
# 8. Create a dataframe "non_smoker" for all non-smoker male employees

# %%
non_smoker=employee[(employee['sex']=='male') & (employee['smoke']=='no')]
non_smoker
# Out:
#           id  age   sex     bmi  dependent  alcohol smoke       zone  \
# 1     i10013   18  male  33.770          1  weekend    no      south
# 2     i10014   28  male  33.000          3   rarely    no      south
# 3     i10015   33  male  22.705          0    daily    no  northwest
# 4     i10016   32  male  28.880          0    party    no  northwest
# 8     i10020   37  male  29.830          2    party    no      north
# ...      ...  ...   ...     ...        ...      ...   ...        ...
# 1324  i11336   31  male  25.935          1    daily    no       west
# 1325  i11337   61  male  33.535          0    party    no       east
# 1327  i11339   51  male  30.030          1    daily    no  southeast
# 1329  i11341   52  male  38.600          2    party    no  southwest
# 1333  i11345   50  male  30.970          3       no    no       west
#
#       expenditure
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# 8      6406.41070
# ...           ...
# ...

# %% [markdown]
# There are 517 non-smoker male employees.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %%
#9. Create a dataframe "non_alcoholic" for all male employees who do not consume alcohol

# %%
non_alcoholic=employee[(employee['sex']=='male') & (employee['alcohol']=='no')]
non_alcoholic
# Out:
#           id  age   sex     bmi  dependent alcohol smoke       zone  \
# 18    i10030   56  male  40.300          0      no    no  southwest
# 24    i10036   37  male  28.025          2      no    no  northwest
# 28    i10040   23  male  17.385          1      no    no  northwest
# 37    i10049   26  male  20.800          0      no    no  southwest
# 38    i10050   35  male  36.670          1      no   yes      north
# ...      ...  ...   ...     ...        ...     ...   ...        ...
# 1291  i11303   19  male  34.900          0      no   yes  southwest
# 1301  i11313   62  male  30.875          3      no   yes       west
# 1310  i11322   42  male  26.315          1      no    no       west
# 1320  i11332   31  male  31.065          3      no    no       west
# 1333  i11345   50  male  30.970          3      no    no       west
#
#       expenditure
# 18    10602.38500
# 24     6203.90175
# 28     2775.19215
# 37     2302.30000
# 38    39774.27630
# ...           ...
# ...

# %% [markdown]
# There are 147 male employees who do not drink alcohol.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %%
#10. Create a dataframe called "non_smoking_alcoholic" with the men employees who do not smoke and consume alcohol. 
#The dataframe should contain columns id, smoke, alcohol

# %%
g=employee[(employee['sex']=='male') & (employee['smoke']=='no') &(employee['alcohol']=='no') ]
g
# Out:
#           id  age   sex     bmi  dependent alcohol smoke       zone  \
# 18    i10030   56  male  40.300          0      no    no  southwest
# 24    i10036   37  male  28.025          2      no    no  northwest
# 28    i10040   23  male  17.385          1      no    no  northwest
# 37    i10049   26  male  20.800          0      no    no  southwest
# 67    i10079   40  male  26.315          1      no    no  northwest
# ...      ...  ...   ...     ...        ...     ...   ...        ...
# 1261  i11273   28  male  37.100          1      no    no  southwest
# 1270  i11282   26  male  33.915          1      no    no       west
# 1310  i11322   42  male  26.315          1      no    no       west
# 1320  i11332   31  male  31.065          3      no    no       west
# 1333  i11345   50  male  30.970          3      no    no       west
#
#       expenditure
# 18    10602.38500
# 24     6203.90175
# 28     2775.19215
# 37     2302.30000
# 67     6389.37785
# ...           ...
# ...

# %%
non_smoking_alcoholic=pd.DataFrame(g)
non_smoking_alcoholic[["id", "smoke", "alcohol"]]
# Out:
#           id smoke alcohol
# 18    i10030    no      no
# 24    i10036    no      no
# 28    i10040    no      no
# 37    i10049    no      no
# 67    i10079    no      no
# ...      ...   ...     ...
# 1261  i11273    no      no
# 1270  i11282    no      no
# 1310  i11322    no      no
# 1320  i11332    no      no
# 1333  i11345    no      no
#
# [109 rows x 3 columns]

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %%
# 11.What is the count for each zone with respect to number of dependent

# %%
#east, west, south, north, northeast, southeast, southwest, northwest are the kind of zones

east=employee[(employee['zone']=='east')]
east_d=east[['dependent']].count()
print ("The count of dependents in East Zone is", east_d)

west=employee[(employee['zone']=='west')]
west_d=west[['dependent']].count()
print ("The count of dependents in West Zone is", west_d)

south=employee[(employee['zone']=='south')]
south_d=south[['dependent']].count()
print ("The count of dependents in South Zone is", south_d)

north=employee[(employee['zone']=='north')]
north_d=north[['dependent']].count()
print ("The count of dependents in North Zone is", north_d)

northeast=employee[(employee['zone']=='northeast')]
northeast_d=northeast[['dependent']].count()
print ("The count of dependents in North East Zone is", northeast_d)

northwest=employee[(employee['zone']=='northwest')]
northwest_d=northwest[['dependent']].count()
print ("The count of dependents in North West Zone is", northwest_d)

southeast=employee[(employee['zone']=='southeast')]
southeast_d=southeast[['dependent']].count()
print ("The count of dependents in South East Zone is", southeast_d)

southwest=employee[(employee['zone']=='southwest')]
southwest_d=southwest[['dependent']].count()
print ("The count of dependents in South West Zone is", southwest_d)
# Out:
# The count of dependents in East Zone is dependent    262
# dtype: int64
# The count of dependents in West Zone is dependent    254
# dtype: int64
# The count of dependents in South Zone is dependent    84
# dtype: int64
# The count of dependents in North Zone is dependent    70
# dtype: int64
# The count of dependents in North East Zone is dependent    74
# dtype: int64
# The count of dependents in North West Zone is dependent    145
# dtype: int64
# The count of dependents in South East Zone is dependent    198
# dtype: int64
# The count of dependents in South West Zone is dependent    251
# dtype: int64

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
plt.figure(figsize=(14,6))
# %matplotlib inline

# %%
 #12. Classify the employees into 3 categories.
 #Category 1 : employees below 18.5 bmi - underweight
 #Category 2 : employees with bmi in the range of 18.5 to 24.9 - fit
 #Category 3 : employee with bmi over 24.9 - overweight
 #What is the average expenditure of employees in each category.
 #Display the bar chart for the same

# %%
#category1: underweight
category1=employee[(employee['bmi']<18.5)]
underweight=pd.DataFrame(category1)
underweight
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 28    i10040   23    male  17.385          1       no    no  northwest
# 128   i10140   32  female  17.765          2  weekend   yes  northwest
# 172   i10184   18    male  15.960          0    party    no      north
# 198   i10210   51  female  18.050          0  weekend    no  northwest
# 232   i10244   19  female  17.800          0    party    no  southwest
# 250   i10262   18    male  17.290          2    party   yes      north
# 380   i10392   27  female  17.955          2    party   yes       east
# 410   i10422   19    male  17.480          0  weekend    no       west
# 412   i10424   26  female  17.195          2       no   yes       east
# 428   i10440   21  female  16.815          1    daily    no       east
# 680   i10692   21  female  17.400          1  weekend    no       west
# 821   i10833   26    male  17.670          0       no    no  northwest
# ...

# %%
print ("Count of underweight employees is", underweight['id'].count())
avg1=underweight[['expenditure']].mean()
print ("Average expenditure of employees in Category1", avg1)
# Out:
# Count of underweight employees is 20
# Average expenditure of employees in Category1 expenditure    8852.200585
# dtype: float64

# %%
#category2: fit
category2=employee[(employee['bmi']>18.5) & (employee['bmi']<24.9) ]
fit=pd.DataFrame(category2)
fit
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 15    i10027   19    male  24.600          1    party    no  southwest
# 17    i10029   23    male  23.845          0  weekend    no      north
# 26    i10038   63  female  23.085          0  weekend    no      north
# 35    i10047   19    male  20.425          0    party    no  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1304  i11316   42    male  24.605          2    daily   yes       east
# 1306  i11318   29  female  21.850          0  weekend   yes       east
# 1314  i11326   30  female  23.655          3    daily   yes       west
# 1316  i11328   19  female  20.600          0  weekend    no  southwest
# 1328  i11340   23  female  24.225          2  weekend    no       east
#
#       expenditure
# 3     21984.47061
# 15     1837.23700
# 17     2395.17155
# 26    14451.83515
# ...

# %%
print ("Count of fit employees is", fit['id'].count())
avg2=fit[['expenditure']].mean()
print ("Average expenditure of employees in Category2", avg2)
# Out:
# Count of fit employees is 221
# Average expenditure of employees in Category2 expenditure    10404.900084
# dtype: float64

# %%
#category3: overweight
category3=employee[(employee['bmi']>24.9)]
overweight=pd.DataFrame(category3)
overweight
# Out:
#           id  age     sex    bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.90          0    daily   yes  southwest
# 1     i10013   18    male  33.77          1  weekend    no      south
# 2     i10014   28    male  33.00          3   rarely    no      south
# 4     i10016   32    male  28.88          0    party    no  northwest
# 5     i10017   31  female  25.74          0       no    no      south
# ...      ...  ...     ...    ...        ...      ...   ...        ...
# 1333  i11345   50    male  30.97          3       no    no       west
# 1334  i11346   18  female  31.92          0    daily    no       east
# 1335  i11347   18  female  36.85          0  weekend    no  southeast
# 1336  i11348   21  female  25.80          0    party    no  southwest
# 1337  i11349   61  female  29.07          0       no   yes       west
#
#       expenditure
# 0      16884.9240
# 1       1725.5523
# 2       4449.4620
# 4       3866.8552
# 5       3756.6216
# ...

# %%
print ("Count of overweight employees is", overweight['id'].count())
avg3=overweight[['expenditure']].mean()
print ("Average expenditure of employees in Category3", avg3)
# Out:
# Count of overweight employees is 1096
# Average expenditure of employees in Category3 expenditure    13936.616823
# dtype: float64

# %%
a=category1['expenditure'].agg('mean')
b=category2['expenditure'].agg('mean')
c=category3['expenditure'].agg('mean')
print (a)
print (b)
print (c)
# Out:
# 8852.200585000002
# 10404.900083891405
# 13936.616823466235

# %%
plt.figure(figsize=(10,8))
plt.xlabel('Categories')
plt.ylabel('Average Expenditure')
sns.barplot(x=['category1 : Underweight', 'category2 : Fit', 'category3 : Overweight'], y=[a,b,c])
plt.show()

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------

# %%
# 13. Draw line plot of expenditure against age and BMI

# %%
fig, ax=plt.subplots(figsize=(6,6))
fig=sns.lineplot(x='expenditure', y='age', data=d)
fig=sns.lineplot(x='expenditure', y='bmi', data=d)
plt.legend(labels=["age", "bmi"])
plt.xlabel('Expenditure', size=10)
plt.ylabel('Age_BMI', size=10)
plt.title('Expenditure against AGE and BMI', size=10)
plt.show()

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------

# %%
# 14. Draw a bar chart to show zone wise average expenditure

# %%
z=pd.pivot_table(employee, values='expenditure',index='zone', aggfunc= np.mean)
zi=z.index
zi
# Out:
# Index(['east', 'north', 'northeast', 'northwest', 'south', 'southeast',
#        'southwest', 'west'],
#       dtype='object', name='zone')

# %%
plt.figure(figsize=(15,7))
plt.bar(zi,z['expenditure'])
plt.xlabel('Zone')
plt.ylabel('Average Expenditure')
# Out:
# Text(0, 0.5, 'Average Expenditure')

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------

# %%
# 15. Draw a bar chart to show smoking and alcoholic habits against average expenditure

# %%
b=pd.pivot_table(employee,values ='expenditure',index='alcohol',columns='smoke',aggfunc=np.mean)
b
# Out:
# smoke             no           yes
# alcohol
# daily    8462.115558  31160.402608
# no       8628.618182  32224.657378
# party    8295.247250  31487.938163
# rarely   5785.022944  31881.367379
# weekend  8784.631185  33592.294629

# %%
X=b.index
X_axis = np.arange(len(X))
Ysmoke=b['no']
Zsmoke=b['yes']
plt.bar(X_axis+0.2 , Ysmoke, 0.4, label = 'Non-Smokers')
plt.bar(X_axis -0.2, Zsmoke, 0.4, label = 'Smokers')
plt.xticks(X_axis,X)
plt.xlabel('Drinking Habits')
plt.ylabel('Average Expenditure')
plt.legend()

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------

# %%
# 16. Draw pie chart for alcohol consumption habits

# %%
daily=employee[(employee['alcohol']=='daily')]
daily_c=daily['id'].count()
print ("Employees who drink daily", daily_c)

weekend=employee[(employee['alcohol']=='weekend')]
weekend_c=weekend['id'].count()
print ("Employees who drink on weekends", weekend_c)

party=employee[(employee['alcohol']=='party')]
party_c=party['id'].count()
print ("Employees who drink in party", party_c)

no=employee[(employee['alcohol']=='no')]
no_c=no['id'].count()
print ("Employees who dont drink", no_c)

rarely=employee[(employee['alcohol']=='rarely')]
rarely_c=rarely['id'].count()
print ("Employees who drink rarely", rarely_c)
# Out:
# Employees who drink daily 395
# Employees who drink on weekends 347
# Employees who drink in party 278
# Employees who dont drink 259
# Employees who drink rarely 59

# %%
consumption=[daily_c, weekend_c, party_c, no_c, rarely_c]
l=['Daily', 'Weekend', 'Party', 'No', 'Rarely']
plt.pie(consumption, labels=l, autopct='%0.1f%%')
plt.show()

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %%
#17. Draw scatterplot to see the relation between age and expenditure, keep smoking habit as hue

# %%
sns.scatterplot(x=employee['age'], y=employee['expenditure'], hue=employee['smoke'])
plt.show()

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %%
# 18. Draw distribution plot of expenditure

# %%
sns.distplot(employee['expenditure'])
plt.show()

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %%
# 19. Display the pairplot

# %%
plt.figure(figsize = (15,8))
sns.pairplot(employee)
plt.show()

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------

# %%
# 20. Display heatmap for the data

# %%
plt.figure(figsize=(10,7))
sns.heatmap(employee.corr(), annot=True)
plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------
